# %%
#Import the required libraries
import numpy as np
import pandas as pd
import math
import random
import warnings
warnings.filterwarnings('ignore')

# %%
#Program Constants

r=1.5
a=1
b=25
c=600
CAP_SCS = 200
CAP_FCS = 400

# %%
#Network Tuning Parameters

NETWORK_SLACK = 1.5
NETWORK_FACTOR_2020 = 1  #This can be below 1 or above 1 [Should be around 1]
FCS_SWAPS_PER_ITERATION = 15
FCS_SCS_SWAPS_PER_ITERATION = 3
TRY_SCS = False
FCS_SWAP_CYCLES = 25
FCS_SCS_SWAPS_CYCLES = 10
REBUILD_NETWORK_ATTEMPTS = 10
EPOCHS = 10
FCS_SWAP_REDUCTION_PER_EPOCH = 0
FCS_SCS_SWAP_REDUCTION_PER_EPOCH = 0

# %%
df_demand = pd.read_csv('Demand_Forecast_2019_2020.csv')

# %%
#df_infra_original = pd.read_csv('EV_infrastructure.csv')
df_infra_original = pd.read_csv('Optimum_Infra_2019_Slack_1.25.csv')

# %%
OPTIMUM_NETWORK = None 
OPTIMUM_NETWORK_COST = 1000000000

# %%
#Function for computing cost_of_infra
def cost_infra_2019(df_infra):
  total_scs = 0
  total_fcs = 0
  for j in range(len(df_infra)):
    scs_j = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j]
    total_scs += scs_j
    fcs_j = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j]
    total_fcs += fcs_j
  total_cost = total_scs + r * total_fcs
  print(total_scs, total_fcs)
  return total_cost


def cost_infra_2020(df_infra):
  total_scs = 0
  total_fcs = 0
  for j in range(len(df_infra)):
    scs_j = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j] + df_infra['2020_incr_SCS'][j]
    total_scs += scs_j
    fcs_j = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j]  + df_infra['2020_incr_FCS'][j]
    total_fcs += fcs_j
  total_cost = total_scs + r * total_fcs
  print(total_scs, total_fcs)
  return total_cost

# %%
#Provides the total supply avaiable at supply point j
def Smax_j_2019 (j, df_infra):
  scs_j = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j]
  fcs_j = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j]

  return scs_j * CAP_SCS + fcs_j * CAP_FCS

def Smax_j_2020 (j, df_infra):
  scs_j = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j] + df_infra['2020_incr_SCS'][j]
  fcs_j = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j] + df_infra['2020_incr_FCS'][j]

  return scs_j * CAP_SCS + fcs_j * CAP_FCS

# %%
#Provides demand at point i on a given year
def get_D_i (i, year):
  return df_demand[year][i]

# %%
#returns the distance between demand point i and supply point j
def distance (i, j):
  x_i = df_demand['x_coordinate'][i]
  y_i = df_demand['y_coordinate'][i]
  x_j = df_infra_original['x_coordinate'][j]
  y_j = df_infra_original['y_coordinate'][j]

  return math.sqrt( (x_i-x_j) **2 +(y_i - y_j) **2)

# %%
#Increment slow charging station, return true if increment done, false if not done 
def increment_SCS_2019 (j, df_infra):
  if (df_infra['existing_num_FCS'][j] + df_infra['existing_num_SCS'][j] + 
      df_infra['2019_incr_FCS'][j] + df_infra['2019_incr_SCS'][j]) < df_infra['total_parking_slots'][j]:
      
      df_infra['2019_incr_SCS'][j] = df_infra['2019_incr_SCS'][j] + 1

      return True
    
  return False

def increment_SCS_2020 (j, df_infra):
  if (df_infra['existing_num_FCS'][j] + df_infra['existing_num_SCS'][j] + 
      df_infra['2019_incr_FCS'][j] + df_infra['2019_incr_SCS'][j] +
      df_infra['2020_incr_FCS'][j] + df_infra['2020_incr_SCS'][j]) < df_infra['total_parking_slots'][j]:
      
      df_infra['2020_incr_SCS'][j] = df_infra['2020_incr_SCS'][j] + 1

      return True

  return False

# %%
def decrement_SCS_2019 (j, df_infra):
  if df_infra['2019_incr_SCS'][j] > 0:
    df_infra['2019_incr_SCS'][j] = df_infra['2019_incr_SCS'][j] - 1

    return True
    
  return False

def decrement_SCS_2020 (j, df_infra):
  if  df_infra['2020_incr_SCS'][j] > 0:
    df_infra['2020_incr_SCS'][j] = df_infra['2020_incr_SCS'][j] - 1
    return True
    
  return False

# %%
#Increment fast charging station, return true if increment done, false if not done 
def increment_FCS_2019 (j, df_infra):
  if (df_infra['existing_num_FCS'][j] + df_infra['existing_num_SCS'][j] + 
      df_infra['2019_incr_FCS'][j] + df_infra['2019_incr_SCS'][j]) < df_infra['total_parking_slots'][j]:
      
      df_infra['2019_incr_FCS'][j] = df_infra['2019_incr_FCS'][j] + 1

      return True
    
  return False

def increment_FCS_2020 (j, df_infra):
  if (df_infra['existing_num_FCS'][j] + df_infra['existing_num_SCS'][j] + 
      df_infra['2019_incr_FCS'][j] + df_infra['2019_incr_SCS'][j] +
      df_infra['2020_incr_FCS'][j] + df_infra['2020_incr_SCS'][j]) < df_infra['total_parking_slots'][j]:
      
      df_infra['2020_incr_FCS'][j] = df_infra['2020_incr_FCS'][j] + 1

      return True

  return False

# %%
#Decrement fast charging station, return true if increment done, false if not done 
def decrement_FCS_2019 (j, df_infra):
  if df_infra['2019_incr_FCS'][j] > 0:
    df_infra['2019_incr_FCS'][j] = df_infra['2019_incr_FCS'][j] - 1

    return True
    
  return False

def decrement_FCS_2020 (j, df_infra):
  if  df_infra['2020_incr_FCS'][j] > 0:
    df_infra['2020_incr_FCS'][j] = df_infra['2020_incr_FCS'][j] - 1
    return True
    
  return False

# %%
#returns the nearest 100 supply points for a demand point
def nearest_supplies(i):
  nearest_100 = dict()
  nearest_distances = dict()
  for x in range (100):
    nearest_100[x] = 1000
  
  for j in range(len(df_infra_original)):
    distance_i_j = distance (i,j)
    for x in range(100):
      if (nearest_100[x] == 1000):
        nearest_100[x] = j
        nearest_distances[j] = distance_i_j
        break
      else:
        x_j = nearest_100[x]
        distance_i_x = nearest_distances[x_j]
        if(distance_i_j < distance_i_x):
          nearest_100[x] = j
          nearest_distances[j] = distance_i_j

          for y in range (x+1, 100):
            temp = nearest_100[y]
            nearest_100[y] = x_j
            x_j = temp
          break
  return list(nearest_100.values())

# %%
def total_demand(year):
  return df_demand[year].sum()

def total_supply_2019(df_infra):
  total_supply = 0
  for j in range(len(df_infra)):
    total_supply = total_supply + Smax_j_2019 (j, df_infra)
  return total_supply

def total_supply_2020(df_infra):
  total_supply = 0
  for j in range(len(df_infra)):
    total_supply = total_supply + Smax_j_2020 (j, df_infra)
  return total_supply

# %%
def allocate_fast_chargers_randomly(num_chargers, year, df_infra):
  print('Allocating Fast Chargers Randomly')
  for charger in range(num_chargers):
    while (True):
      random_supply_point = random.randint(0, 99)
      flag = False
      if (year == '2019'):
        flag = increment_FCS_2019(random_supply_point, df_infra)
      elif (year == '2020'):
        flag = increment_FCS_2020(random_supply_point, df_infra)
      if flag:
        break

# %%
def redistribute_fast_chargers_randomly(year, df_infra):
  
  for charger in range(FCS_SWAPS_PER_ITERATION):
    while(True):
      random_supply_point = random.randint(0, 99)
      flag = False
      if (year == '2019'):
        flag = decrement_FCS_2019(random_supply_point, df_infra)
      elif (year == '2020'):
        flag = decrement_FCS_2020(random_supply_point, df_infra)
      if flag:
        break

  for charger in range(FCS_SWAPS_PER_ITERATION):
    while (True):
      random_supply_point = random.randint(0, 99)
      flag = False
      if (year == '2019'):
        flag = increment_FCS_2019(random_supply_point, df_infra)
      elif (year == '2020'):
        flag = increment_FCS_2020(random_supply_point, df_infra)
      if flag:
        break

# %%
def swap_fast_chargers_with_slow_chargers(year, df_infra):
  
  for charger in range(FCS_SCS_SWAPS_PER_ITERATION):
    while(True):
      random_supply_point = random.randint(0, 99)
      flag = False
      if (year == '2019'):
        flag = decrement_FCS_2019(random_supply_point, df_infra)
      elif (year == '2020'):
        flag = decrement_FCS_2020(random_supply_point, df_infra)
      if flag:
        break
  
  for charger in range(FCS_SCS_SWAPS_PER_ITERATION * 2):
    while (True):
      random_supply_point = random.randint(0, 99)
      flag = False
      if (year == '2019'):
        flag = increment_SCS_2019(random_supply_point, df_infra)
      elif (year == '2020'):
        flag = increment_SCS_2020(random_supply_point, df_infra)
      if flag:
        break

# %%
#Populates the df_infra_state dataframe with the total capacity of each point
def populate_infra_state(df_infra, df_infra_state, year):
  for j in range(len(df_infra)):
    supply_point_capacity = 0
    if (year == '2019'):
      supply_point_capacity = Smax_j_2019(j, df_infra)
    elif (year == '2020'):
      supply_point_capacity = Smax_j_2020(j, df_infra)
    df_infra_state.loc[len(df_infra_state.index)] = [j, supply_point_capacity, 0, supply_point_capacity]

# %%
def build_greedy_network(df_infra_state, df_solution_network, year):
  '''
  Uses a greedy algorithm to build a network, basically looks at the nearest supply 
  point to connect the given demand point. The input variable df_infra_state 
  takes a populated infra_state with appropriate capacities. The df_solution_network
  is modified by ths function with [year, i, j, Dij, values, and cost]  
  '''

  print('Building the network')
  for i in range(len(df_demand)):
    D_i = get_D_i(i, year)
    nearest_supply_points = nearest_supplies(i)
    for j in nearest_supply_points:
      allocated_capacity = df_infra_state['allocated_capacity'][j]
      balance = df_infra_state['balance'][j]
      if D_i <= balance:
        balance = balance - D_i
        allocated_capacity = allocated_capacity + D_i
        cost = distance(i, j) * D_i
        df_solution_network.loc[len(df_solution_network.index)] = [year, 'DS', i, j, D_i, cost]
        D_i = 0
      else:
        D_i = D_i - balance
        allocated_capacity = allocated_capacity + balance
        cost = distance(i, j) * balance
        df_solution_network.loc[len(df_solution_network.index)] = [year, 'DS', i, j, balance, cost]
        balance = 0
      df_infra_state['allocated_capacity'][j] = allocated_capacity
      df_infra_state['balance'][j] = balance
      if D_i == 0:
        break
    if D_i > 0:
      raise Exception('Network cannot be built properly as insufficient infrastructure capacity')
  print('Network Built')

# %%
def build_solution_infra(df_infra, df_solution_infra):
  for j in range(len(df_infra)):
    value = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j]
    cost = c * value
    df_solution_infra.loc[len(df_solution_infra)] = [2019, 'SCS', None, j, value, cost]

  for j in range(len(df_infra)):
    value = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j]
    cost = c * r* value
    df_solution_infra.loc[len(df_solution_infra)] = [2019, 'FCS', None, j, value, cost]
  
  for j in range(len(df_infra)):
    value = df_infra['existing_num_SCS'][j] + df_infra['2019_incr_SCS'][j] + df_infra['2020_incr_SCS'][j]
    cost = c * value
    df_solution_infra.loc[len(df_solution_infra)] = [2020, 'SCS', None, j, value, cost]
  
  for j in range(len(df_infra)):
    value = df_infra['existing_num_FCS'][j] + df_infra['2019_incr_FCS'][j] + df_infra['2020_incr_FCS'][j]
    cost = c * r *  value
    df_solution_infra.loc[len(df_solution_infra)] = [2020, 'FCS', None, j, value, cost]

def compute_infra_cost(df_solution_infra, year):
  if (year == '2019'):
    return list(df_solution_infra.groupby('year').sum()['cost'])[0]
  
  if (year == '2020'):
    return list(df_solution_infra.groupby('year').sum()['cost'])[1]

# %%
''' Main script '''

#year = '2019'

#incremental_supply_requirement_2019 = total_demand(year) - total_supply_2019(df_infra_original)
#incremental_fast_chargers_2019 = int((incremental_supply_requirement_2019 / CAP_FCS) * (1+ NETWORK_SLACK)) + 1
#df_infra = df_infra_original.copy()
#allocate_fast_chargers_randomly(incremental_fast_chargers_2019, year, df_infra)

year = '2020'

incremental_supply_requirement_2020 = total_supply_2020(df_infra_original) * (total_demand(year) / total_demand('2019') - 1)
incremental_fast_chargers_2020 = max((int((incremental_supply_requirement_2020 / CAP_FCS) * (NETWORK_FACTOR_2020)) + 1), 25)
df_infra = df_infra_original.copy()
allocate_fast_chargers_randomly(incremental_fast_chargers_2020, year, df_infra)

for x in range(EPOCHS):
  print('====================================EPOCH: ', x+1, '===============================================')

  #After every epoch reduce the number of swaps per iteration
  FCS_SWAPS_PER_ITERATION = FCS_SWAPS_PER_ITERATION - FCS_SWAP_REDUCTION_PER_EPOCH
  FCS_SCS_SWAPS_PER_ITERATION = FCS_SCS_SWAPS_PER_ITERATION - FCS_SCS_SWAP_REDUCTION_PER_EPOCH

  for y in range (FCS_SWAP_CYCLES + 1): #+1 has been added as the 1st swap cycle will be skipped
    
    # Start swaps only after the 1st cycle is completed
    if (y > 0): 
      print('FCS SWAP CYCLE: ', y)
      redistribute_fast_chargers_randomly(year, df_infra)

    df_solution_network = pd.DataFrame(columns = ['year', 'data_type', 'demand_point_index', 'supply_point_index', 
                                                  'value', 'cost'])
    df_solution_infra = pd.DataFrame(columns = ['year', 'data_type', 'demand_point_index', 'supply_point_index', 
                                                'value', 'cost'])
    df_infra_state = pd.DataFrame (columns = ['supply_point_index', 'supply_point_capacity', 
                                              'allocated_capacity', 'balance'])

    populate_infra_state(df_infra, df_infra_state, year)
    build_greedy_network(df_infra_state, df_solution_network, year)
    build_solution_infra(df_infra, df_solution_infra)
    
    infra_cost = compute_infra_cost(df_solution_infra, year)
    print('Cost of Infrastructure: ', infra_cost)
    cust_satisfaction_cost = df_solution_network['cost'].sum()
    print('Cost of Customer Unsatisfaction: ', cust_satisfaction_cost)
    total_cost = infra_cost + cust_satisfaction_cost
    print('Total Cost: ', total_cost)

    if(total_cost) < OPTIMUM_NETWORK_COST:
      print('**********New optimum network found with cost: ', total_cost,'**********')
      OPTIMUM_NETWORK_COST = total_cost
      OPTIMUM_NETWORK = {'Optimum Infra': df_infra, 
                      'Solution Network' : df_solution_network, 
                      'Solution Infra': df_solution_infra}

    df_infra = OPTIMUM_NETWORK['Optimum Infra'].copy()
    

  '''
  IMPORTANT: The code below tries to keep adding more slow chargers as long as it finds
             better solutions with additional slow chargers
  '''
  #df_infra_before_SCS_SWAP = OPTIMUM_NETWORK['Optimum Infra'].copy()
  for y in range (FCS_SCS_SWAPS_CYCLES):
    print('SCS SWAP CYCLE: ', y +1)
    #df_infra = df_infra_before_SCS_SWAP.copy()
    swap_fast_chargers_with_slow_chargers(year, df_infra)

    df_solution_network = pd.DataFrame(columns = ['year', 'data_type', 'demand_point_index', 'supply_point_index', 
                                                  'value', 'cost'])
    df_solution_infra = pd.DataFrame(columns = ['year', 'data_type', 'demand_point_index', 'supply_point_index', 
                                                'value', 'cost'])
    df_infra_state = pd.DataFrame (columns = ['supply_point_index', 'supply_point_capacity', 
                                              'allocated_capacity', 'balance'])

    populate_infra_state(df_infra, df_infra_state, year)
    build_greedy_network(df_infra_state, df_solution_network, year)
    build_solution_infra(df_infra, df_solution_infra)
    
    infra_cost = compute_infra_cost(df_solution_infra, year)
    print('Cost of Infrastructure: ', infra_cost)
    cust_satisfaction_cost = df_solution_network['cost'].sum()
    print('Cost of Customer Unsatisfaction: ', cust_satisfaction_cost)
    total_cost = infra_cost + cust_satisfaction_cost
    print('Total Cost: ', total_cost)

    if(total_cost) < OPTIMUM_NETWORK_COST:
      print('**********New optimum network found with cost: ', total_cost,'**********')
      OPTIMUM_NETWORK_COST = total_cost
      OPTIMUM_NETWORK = {'Optimum Infra': df_infra, 
                      'Solution Network' : df_solution_network, 
                      'Solution Infra': df_solution_infra}

    df_infra = OPTIMUM_NETWORK['Optimum Infra'].copy()
# Out:
# Allocating Fast Chargers Randomly
# ====================================EPOCH:  1 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2312407.015828346
# Total Cost:  3837907.015828346
# **********New optimum network found with cost:  3837907.015828346 **********
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2319732.133853254
# Total Cost:  3845232.133853254
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2328974.549897236
# Total Cost:  3854474.549897236
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2307094.924189062
# Total Cost:  3832594.924189062
# **********New optimum network found with cost:  3832594.924189062 **********
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2299674.3145736926
# Total Cost:  3825174.3145736926
# **********New optimum network found with cost:  3825174.3145736926 **********
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2315917.2802239833
# Total Cost:  3841417.2802239833
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2307155.3678616374
# Total Cost:  3832655.3678616374
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2308020.7866738355
# Total Cost:  3833520.7866738355
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2303115.6868414083
# Total Cost:  3828615.6868414083
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2310041.271000118
# Total Cost:  3835541.271000118
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2302922.8542707074
# Total Cost:  3828422.8542707074
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2302321.682886263
# Total Cost:  3827821.682886263
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2298002.773339328
# Total Cost:  3823502.773339328
# **********New optimum network found with cost:  3823502.773339328 **********
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2315558.402574207
# Total Cost:  3841058.402574207
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2299674.852532001
# Total Cost:  3825174.852532001
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2293751.8021171084
# Total Cost:  3819251.8021171084
# **********New optimum network found with cost:  3819251.8021171084 **********
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2298095.7961145313
# Total Cost:  3823595.7961145313
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2301444.875734973
# Total Cost:  3826944.875734973
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2296200.713803995
# Total Cost:  3821700.713803995
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2289359.3450978226
# Total Cost:  3814859.3450978226
# **********New optimum network found with cost:  3814859.3450978226 **********
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2288622.3195033837
# Total Cost:  3814122.3195033837
# **********New optimum network found with cost:  3814122.3195033837 **********
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2310428.1411796687
# Total Cost:  3835928.1411796687
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2285033.339765055
# Total Cost:  3810533.339765055
# **********New optimum network found with cost:  3810533.339765055 **********
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2281502.1849545687
# Total Cost:  3807002.1849545687
# **********New optimum network found with cost:  3807002.1849545687 **********
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2291683.6902290797
# Total Cost:  3817183.6902290797
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1525500.0
# Cost of Customer Unsatisfaction:  2281185.898051126
# Total Cost:  3806685.898051126
# **********New optimum network found with cost:  3806685.898051126 **********
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1526400.0
# Cost of Customer Unsatisfaction:  2281144.3587610824
# Total Cost:  3807544.3587610824
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1526400.0
# Cost of Customer Unsatisfaction:  2279132.9817188215
# Total Cost:  3805532.9817188215
# **********New optimum network found with cost:  3805532.9817188215 **********
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2284010.3503001183
# Total Cost:  3811310.3503001183
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2278845.2303281124
# Total Cost:  3806145.2303281124
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2278725.1732122186
# Total Cost:  3806025.1732122186
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2277557.470508794
# Total Cost:  3804857.470508794
# **********New optimum network found with cost:  3804857.470508794 **********
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2283213.3253307063
# Total Cost:  3811413.3253307063
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2280923.4087291704
# Total Cost:  3809123.4087291704
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2280724.944858232
# Total Cost:  3808924.944858232
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2282488.340206164
# Total Cost:  3810688.340206164
# ====================================EPOCH:  2 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2277557.470508794
# Total Cost:  3804857.470508794
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2297014.8159415172
# Total Cost:  3824314.8159415172
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2289819.389631714
# Total Cost:  3817119.389631714
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2284335.6133905584
# Total Cost:  3811635.6133905584
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2289351.9728587214
# Total Cost:  3816651.9728587214
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2283901.176000382
# Total Cost:  3811201.176000382
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2292461.262776012
# Total Cost:  3819761.262776012
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2276602.2711732597
# Total Cost:  3803902.2711732597
# **********New optimum network found with cost:  3803902.2711732597 **********
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2277589.906756024
# Total Cost:  3804889.906756024
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2292376.8464508876
# Total Cost:  3819676.8464508876
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2289435.736911877
# Total Cost:  3816735.736911877
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2280201.9888805067
# Total Cost:  3807501.9888805067
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2283622.4668107377
# Total Cost:  3810922.4668107377
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2279500.0545356246
# Total Cost:  3806800.0545356246
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2296398.688239002
# Total Cost:  3823698.688239002
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2282249.903767667
# Total Cost:  3809549.903767667
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2280044.0609348807
# Total Cost:  3807344.0609348807
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2293798.951359699
# Total Cost:  3821098.951359699
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2280012.260671829
# Total Cost:  3807312.260671829
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2282440.1214849893
# Total Cost:  3809740.1214849893
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2281771.4134050915
# Total Cost:  3809071.4134050915
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2282341.5725002214
# Total Cost:  3809641.5725002214
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2283664.339485623
# Total Cost:  3810964.339485623
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2279844.0423207446
# Total Cost:  3807144.0423207446
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2279512.7258632565
# Total Cost:  3806812.7258632565
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1527300.0
# Cost of Customer Unsatisfaction:  2285585.6876184866
# Total Cost:  3812885.6876184866
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2276213.493486477
# Total Cost:  3804413.493486477
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2279367.968099965
# Total Cost:  3807567.968099965
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1528200.0
# Cost of Customer Unsatisfaction:  2275189.637040528
# Total Cost:  3803389.637040528
# **********New optimum network found with cost:  3803389.637040528 **********
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1529100.0
# Cost of Customer Unsatisfaction:  2274618.5452374546
# Total Cost:  3803718.5452374546
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1529100.0
# Cost of Customer Unsatisfaction:  2277559.4945329316
# Total Cost:  3806659.4945329316
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1529100.0
# Cost of Customer Unsatisfaction:  2273178.733205055
# Total Cost:  3802278.733205055
# **********New optimum network found with cost:  3802278.733205055 **********
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1530000.0
# Cost of Customer Unsatisfaction:  2272470.193859374
# Total Cost:  3802470.193859374
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1530000.0
# Cost of Customer Unsatisfaction:  2272276.155706714
# Total Cost:  3802276.155706714
# **********New optimum network found with cost:  3802276.155706714 **********
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2269469.053445908
# Total Cost:  3800369.053445908
# **********New optimum network found with cost:  3800369.053445908 **********
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1531800.0
# Cost of Customer Unsatisfaction:  2272306.1170669803
# Total Cost:  3804106.1170669803
# ====================================EPOCH:  3 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2269469.053445908
# Total Cost:  3800369.053445908
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2275299.542101131
# Total Cost:  3806199.542101131
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2280340.1036498277
# Total Cost:  3811240.1036498277
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2279059.0652283956
# Total Cost:  3809959.0652283956
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2272026.564953788
# Total Cost:  3802926.564953788
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2268359.377729723
# Total Cost:  3799259.377729723
# **********New optimum network found with cost:  3799259.377729723 **********
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2271269.85853054
# Total Cost:  3802169.85853054
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2267197.683403246
# Total Cost:  3798097.683403246
# **********New optimum network found with cost:  3798097.683403246 **********
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2269754.202823084
# Total Cost:  3800654.202823084
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2270110.0762553113
# Total Cost:  3801010.0762553113
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2268661.8511250657
# Total Cost:  3799561.8511250657
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2265945.60183347
# Total Cost:  3796845.60183347
# **********New optimum network found with cost:  3796845.60183347 **********
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2271109.249175102
# Total Cost:  3802009.249175102
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2268203.1480199182
# Total Cost:  3799103.1480199182
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2272325.0551757347
# Total Cost:  3803225.0551757347
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2267528.083537489
# Total Cost:  3798428.083537489
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2267739.4692808003
# Total Cost:  3798639.4692808003
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2271389.467479608
# Total Cost:  3802289.467479608
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2266684.9386304854
# Total Cost:  3797584.9386304854
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2273534.9004279263
# Total Cost:  3804434.9004279263
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2274447.2195210895
# Total Cost:  3805347.2195210895
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2266498.3160000388
# Total Cost:  3797398.3160000388
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2267437.0755404974
# Total Cost:  3798337.0755404974
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2269844.251380575
# Total Cost:  3800744.251380575
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2273420.8547466244
# Total Cost:  3804320.8547466244
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1530900.0
# Cost of Customer Unsatisfaction:  2266371.965880627
# Total Cost:  3797271.965880627
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1531800.0
# Cost of Customer Unsatisfaction:  2264954.7840571892
# Total Cost:  3796754.7840571892
# **********New optimum network found with cost:  3796754.7840571892 **********
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2264842.5453731823
# Total Cost:  3797542.5453731823
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2265248.1946790535
# Total Cost:  3797948.1946790535
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2262379.8877256415
# Total Cost:  3795079.8877256415
# **********New optimum network found with cost:  3795079.8877256415 **********
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2262513.009897065
# Total Cost:  3796113.009897065
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2266191.0609364836
# Total Cost:  3799791.0609364836
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2264649.9377293773
# Total Cost:  3798249.9377293773
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2262668.15598007
# Total Cost:  3796268.15598007
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2262705.068196517
# Total Cost:  3796305.068196517
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2262173.4157091044
# Total Cost:  3795773.4157091044
# ====================================EPOCH:  4 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2262379.8877256415
# Total Cost:  3795079.8877256415
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2274209.421850874
# Total Cost:  3806909.421850874
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2261917.5488214297
# Total Cost:  3794617.5488214297
# **********New optimum network found with cost:  3794617.5488214297 **********
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2260242.645718732
# Total Cost:  3792942.645718732
# **********New optimum network found with cost:  3792942.645718732 **********
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2257160.111513465
# Total Cost:  3789860.111513465
# **********New optimum network found with cost:  3789860.111513465 **********
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249200.2884896267
# Total Cost:  3781900.2884896267
# **********New optimum network found with cost:  3781900.2884896267 **********
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249165.627631593
# Total Cost:  3781865.627631593
# **********New optimum network found with cost:  3781865.627631593 **********
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2252589.7608403107
# Total Cost:  3785289.7608403107
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2260355.124229341
# Total Cost:  3793055.124229341
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2260550.587257853
# Total Cost:  3793250.587257853
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2255228.5747408443
# Total Cost:  3787928.5747408443
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2254140.376571729
# Total Cost:  3786840.376571729
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253756.721229541
# Total Cost:  3786456.721229541
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247055.8559554666
# Total Cost:  3779755.8559554666
# **********New optimum network found with cost:  3779755.8559554666 **********
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251071.9172401614
# Total Cost:  3783771.9172401614
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247811.8603496007
# Total Cost:  3780511.8603496007
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249200.3539541843
# Total Cost:  3781900.3539541843
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2248867.364260139
# Total Cost:  3781567.364260139
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2257670.9830920426
# Total Cost:  3790370.9830920426
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2254695.6578565096
# Total Cost:  3787395.6578565096
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253481.518477259
# Total Cost:  3786181.518477259
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2260161.1754973475
# Total Cost:  3792861.1754973475
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2246256.649236298
# Total Cost:  3778956.649236298
# **********New optimum network found with cost:  3778956.649236298 **********
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253788.982436023
# Total Cost:  3786488.982436023
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2252966.8358834274
# Total Cost:  3785666.8358834274
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2250647.0763767846
# Total Cost:  3783347.0763767846
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2247111.9189144294
# Total Cost:  3780711.9189144294
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2250255.286994792
# Total Cost:  3783855.286994792
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2250302.09038595
# Total Cost:  3783902.09038595
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2248262.142384162
# Total Cost:  3781862.142384162
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2247579.6677404074
# Total Cost:  3781179.6677404074
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2248748.618365312
# Total Cost:  3782348.618365312
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2249671.972057416
# Total Cost:  3783271.972057416
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2247518.1112682484
# Total Cost:  3781118.1112682484
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2248474.8546853047
# Total Cost:  3782074.8546853047
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2247152.7163338196
# Total Cost:  3780752.7163338196
# ====================================EPOCH:  5 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2246256.649236298
# Total Cost:  3778956.649236298
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251231.423174191
# Total Cost:  3783931.423174191
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2261124.7713725506
# Total Cost:  3793824.7713725506
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2258354.4943740712
# Total Cost:  3791054.4943740712
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251518.213152628
# Total Cost:  3784218.213152628
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247320.0756918006
# Total Cost:  3780020.0756918006
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253997.8141420814
# Total Cost:  3786697.8141420814
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2260162.9204201903
# Total Cost:  3792862.9204201903
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249467.4735339023
# Total Cost:  3782167.4735339023
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251817.8176717646
# Total Cost:  3784517.8176717646
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253371.8415248888
# Total Cost:  3786071.8415248888
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251187.575277741
# Total Cost:  3783887.575277741
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249188.3871329026
# Total Cost:  3781888.3871329026
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253115.726392838
# Total Cost:  3785815.726392838
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2255181.085418636
# Total Cost:  3787881.085418636
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2253093.3096609856
# Total Cost:  3785793.3096609856
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2256511.113085516
# Total Cost:  3789211.113085516
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2257273.683605815
# Total Cost:  3789973.683605815
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2245249.7986625293
# Total Cost:  3777949.7986625293
# **********New optimum network found with cost:  3777949.7986625293 **********
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2239163.8645449854
# Total Cost:  3771863.8645449854
# **********New optimum network found with cost:  3771863.8645449854 **********
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2242177.676334141
# Total Cost:  3774877.676334141
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2242082.5934836688
# Total Cost:  3774782.5934836688
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247259.621062305
# Total Cost:  3779959.621062305
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2246608.829741611
# Total Cost:  3779308.829741611
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2242448.4658057406
# Total Cost:  3775148.4658057406
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249173.0671344083
# Total Cost:  3781873.0671344083
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2243102.3489303477
# Total Cost:  3776702.3489303477
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2239378.9485597485
# Total Cost:  3772978.9485597485
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2240133.511583424
# Total Cost:  3773733.511583424
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2242393.5919848457
# Total Cost:  3775993.5919848457
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2241215.9379455475
# Total Cost:  3774815.9379455475
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2240033.732318923
# Total Cost:  3773633.732318923
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2240753.6169403577
# Total Cost:  3774353.6169403577
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2240642.78326039
# Total Cost:  3774242.78326039
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2238754.004100871
# Total Cost:  3772354.004100871
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2243766.264734486
# Total Cost:  3777366.264734486
# ====================================EPOCH:  6 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2239163.8645449854
# Total Cost:  3771863.8645449854
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2243830.7523214985
# Total Cost:  3776530.7523214985
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249690.7323376182
# Total Cost:  3782390.7323376182
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251162.6820938797
# Total Cost:  3783862.6820938797
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247698.8009144124
# Total Cost:  3780398.8009144124
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2238576.6131465826
# Total Cost:  3771276.6131465826
# **********New optimum network found with cost:  3771276.6131465826 **********
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2242053.5478502773
# Total Cost:  3774753.5478502773
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2250939.6462605884
# Total Cost:  3783639.6462605884
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2249594.0846841424
# Total Cost:  3782294.0846841424
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2239559.5798285864
# Total Cost:  3772259.5798285864
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2245476.9982401603
# Total Cost:  3778176.9982401603
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2244952.239161568
# Total Cost:  3777652.239161568
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2241111.759235963
# Total Cost:  3773811.759235963
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2251753.5680820574
# Total Cost:  3784453.5680820574
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2245575.6634738185
# Total Cost:  3778275.6634738185
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2235132.288997306
# Total Cost:  3767832.288997306
# **********New optimum network found with cost:  3767832.288997306 **********
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2234059.5169850755
# Total Cost:  3766759.5169850755
# **********New optimum network found with cost:  3766759.5169850755 **********
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2243636.339447229
# Total Cost:  3776336.339447229
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2247378.15121616
# Total Cost:  3780078.15121616
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2234520.0102267293
# Total Cost:  3767220.0102267293
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2238124.029064581
# Total Cost:  3770824.029064581
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2238233.033974505
# Total Cost:  3770933.033974505
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2240180.289572549
# Total Cost:  3772880.289572549
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2243876.602866489
# Total Cost:  3776576.602866489
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2246785.6886335937
# Total Cost:  3779485.6886335937
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1532700.0
# Cost of Customer Unsatisfaction:  2239942.6632289
# Total Cost:  3772642.6632289
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2233552.09936433
# Total Cost:  3767152.09936433
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2235490.688949747
# Total Cost:  3769090.688949747
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2234513.685501104
# Total Cost:  3768113.685501104
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2235067.3175194515
# Total Cost:  3768667.3175194515
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2233340.324214979
# Total Cost:  3766940.324214979
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2234835.138225402
# Total Cost:  3768435.138225402
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236769.2128555975
# Total Cost:  3770369.2128555975
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2238631.656508862
# Total Cost:  3772231.656508862
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236022.5551355714
# Total Cost:  3769622.5551355714
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2231239.03944867
# Total Cost:  3764839.03944867
# **********New optimum network found with cost:  3764839.03944867 **********
# ====================================EPOCH:  7 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2231239.03944867
# Total Cost:  3764839.03944867
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2243744.0191948316
# Total Cost:  3777344.0191948316
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2244077.243570947
# Total Cost:  3777677.243570947
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2234770.1985877543
# Total Cost:  3768370.1985877543
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2231363.8834882188
# Total Cost:  3764963.8834882188
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2234353.629093185
# Total Cost:  3767953.629093185
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236601.2996389633
# Total Cost:  3770201.2996389633
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2244056.8190221125
# Total Cost:  3777656.8190221125
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2247674.630632027
# Total Cost:  3781274.630632027
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2233299.0857521286
# Total Cost:  3766899.0857521286
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236403.3091056515
# Total Cost:  3770003.3091056515
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2235800.928518672
# Total Cost:  3769400.928518672
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236576.391552793
# Total Cost:  3770176.391552793
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2233625.859032657
# Total Cost:  3767225.859032657
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2242387.0628942885
# Total Cost:  3775987.0628942885
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2237005.0618966874
# Total Cost:  3770605.0618966874
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2238609.98389096
# Total Cost:  3772209.98389096
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2238792.101195057
# Total Cost:  3772392.101195057
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2242985.0518753217
# Total Cost:  3776585.0518753217
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2243984.5156817585
# Total Cost:  3777584.5156817585
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2245920.31586653
# Total Cost:  3779520.31586653
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2236077.2173902728
# Total Cost:  3769677.2173902728
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2242392.8471917943
# Total Cost:  3775992.8471917943
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2241642.342448234
# Total Cost:  3775242.342448234
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2242761.7915331223
# Total Cost:  3776361.7915331223
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1533600.0
# Cost of Customer Unsatisfaction:  2239306.799446545
# Total Cost:  3772906.799446545
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2233975.0912599443
# Total Cost:  3768475.0912599443
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2230986.65567411
# Total Cost:  3765486.65567411
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2231672.829369868
# Total Cost:  3766172.829369868
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2231170.4592227116
# Total Cost:  3765670.4592227116
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2232401.688725307
# Total Cost:  3766901.688725307
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2233255.9205249995
# Total Cost:  3767755.9205249995
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2230776.9498658553
# Total Cost:  3765276.9498658553
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1534500.0
# Cost of Customer Unsatisfaction:  2230044.0539179826
# Total Cost:  3764544.0539179826
# **********New optimum network found with cost:  3764544.0539179826 **********
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2228178.2865258735
# Total Cost:  3763578.2865258735
# **********New optimum network found with cost:  3763578.2865258735 **********
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2228649.48911197
# Total Cost:  3764949.48911197
# ====================================EPOCH:  8 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2228178.2865258735
# Total Cost:  3763578.2865258735
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2228505.4114655023
# Total Cost:  3763905.4114655023
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2233276.7028129864
# Total Cost:  3768676.7028129864
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2236548.142766877
# Total Cost:  3771948.142766877
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# ...
# Cost of Customer Unsatisfaction:  2229084.797021459
# Total Cost:  3764484.797021459
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2236520.8264476648
# Total Cost:  3771920.8264476648
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2229216.8483633352
# Total Cost:  3764616.8483633352
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2234672.358481203
# Total Cost:  3770072.358481203
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2240198.159852816
# Total Cost:  3775598.159852816
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2233254.785849751
# Total Cost:  3768654.785849751
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2227650.5461831773
# Total Cost:  3763050.5461831773
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2231113.2560088444
# Total Cost:  3766513.2560088444
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1535400.0
# Cost of Customer Unsatisfaction:  2227947.286099172
# Total Cost:  3763347.286099172
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2226399.218928482
# Total Cost:  3762699.218928482
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227283.136609383
# Total Cost:  3763583.136609383
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229676.367116829
# Total Cost:  3765976.367116829
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2224569.599345021
# Total Cost:  3760869.599345021
# **********New optimum network found with cost:  3760869.599345021 **********
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2228616.709995663
# Total Cost:  3765816.709995663
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2225343.775402509
# Total Cost:  3762543.775402509
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224243.6166628236
# Total Cost:  3761443.6166628236
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2225387.106006351
# Total Cost:  3762587.106006351
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224374.8000108036
# Total Cost:  3761574.8000108036
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2227061.417502369
# Total Cost:  3764261.417502369
# ====================================EPOCH:  9 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2224569.599345021
# Total Cost:  3760869.599345021
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2230397.9915839178
# Total Cost:  3766697.9915839178
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2231981.8123412486
# Total Cost:  3768281.8123412486
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2228318.664473882
# Total Cost:  3764618.664473882
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2228218.326206195
# Total Cost:  3764518.326206195
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229897.9929505507
# Total Cost:  3766197.9929505507
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2230909.579346622
# Total Cost:  3767209.579346622
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2231451.170432995
# Total Cost:  3767751.170432995
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2237680.9678239278
# Total Cost:  3773980.9678239278
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2237230.348402354
# Total Cost:  3773530.348402354
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2233008.1461396706
# Total Cost:  3769308.1461396706
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232314.9160912028
# Total Cost:  3768614.9160912028
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229148.0213149833
# Total Cost:  3765448.0213149833
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2231229.8810236407
# Total Cost:  3767529.8810236407
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232291.8372644964
# Total Cost:  3768591.8372644964
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2235403.9785457086
# Total Cost:  3771703.9785457086
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2230883.795398362
# Total Cost:  3767183.795398362
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2223243.642079236
# Total Cost:  3759543.642079236
# **********New optimum network found with cost:  3759543.642079236 **********
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2234994.3035375
# Total Cost:  3771294.3035375
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227957.2579142726
# Total Cost:  3764257.2579142726
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232099.895166085
# Total Cost:  3768399.895166085
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2223439.0980419135
# Total Cost:  3759739.0980419135
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232844.8876360077
# Total Cost:  3769144.8876360077
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227454.9299027463
# Total Cost:  3763754.9299027463
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2226786.218358544
# Total Cost:  3763086.218358544
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229489.0322265634
# Total Cost:  3765789.0322265634
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224073.4211118734
# Total Cost:  3761273.4211118734
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2227532.015724429
# Total Cost:  3764732.015724429
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224073.4193118103
# Total Cost:  3761273.4193118103
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2225457.8303799666
# Total Cost:  3762657.8303799666
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223545.181420885
# Total Cost:  3760745.181420885
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224277.0454396824
# Total Cost:  3761477.0454396824
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224806.3006373374
# Total Cost:  3762006.3006373374
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2225362.716307476
# Total Cost:  3762562.716307476
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224666.9919371353
# Total Cost:  3761866.9919371353
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224356.055415471
# Total Cost:  3761556.055415471
# ====================================EPOCH:  10 ===============================================
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2223243.642079236
# Total Cost:  3759543.642079236
# FCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227389.640773492
# Total Cost:  3763689.640773492
# FCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2225606.057138555
# Total Cost:  3761906.057138555
# FCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2234931.0077072997
# Total Cost:  3771231.0077072997
# FCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227792.679583095
# Total Cost:  3764092.679583095
# FCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2228568.765275987
# Total Cost:  3764868.765275987
# FCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2226984.18327411
# Total Cost:  3763284.18327411
# FCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2230948.94483261
# Total Cost:  3767248.94483261
# FCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229575.6073311316
# Total Cost:  3765875.6073311316
# FCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232482.0847883457
# Total Cost:  3768782.0847883457
# FCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2235794.5562229725
# Total Cost:  3772094.5562229725
# FCS SWAP CYCLE:  11
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2235364.3535269126
# Total Cost:  3771664.3535269126
# FCS SWAP CYCLE:  12
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2237644.5697919223
# Total Cost:  3773944.5697919223
# FCS SWAP CYCLE:  13
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227627.4034317755
# Total Cost:  3763927.4034317755
# FCS SWAP CYCLE:  14
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2228127.086441436
# Total Cost:  3764427.086441436
# FCS SWAP CYCLE:  15
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227973.0191973504
# Total Cost:  3764273.0191973504
# FCS SWAP CYCLE:  16
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2227206.9959211005
# Total Cost:  3763506.9959211005
# FCS SWAP CYCLE:  17
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2224842.7421607813
# Total Cost:  3761142.7421607813
# FCS SWAP CYCLE:  18
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2223978.6054380955
# Total Cost:  3760278.6054380955
# FCS SWAP CYCLE:  19
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2229029.256668484
# Total Cost:  3765329.256668484
# FCS SWAP CYCLE:  20
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2230898.4764312394
# Total Cost:  3767198.4764312394
# FCS SWAP CYCLE:  21
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2223978.551732689
# Total Cost:  3760278.551732689
# FCS SWAP CYCLE:  22
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232551.8435066706
# Total Cost:  3768851.8435066706
# FCS SWAP CYCLE:  23
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2231925.7499267673
# Total Cost:  3768225.7499267673
# FCS SWAP CYCLE:  24
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2231798.645002627
# Total Cost:  3768098.645002627
# FCS SWAP CYCLE:  25
# Building the network
# Network Built
# Cost of Infrastructure:  1536300.0
# Cost of Customer Unsatisfaction:  2232990.3082088367
# Total Cost:  3769290.3082088367
# SCS SWAP CYCLE:  1
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2222813.727471429
# Total Cost:  3760013.727471429
# SCS SWAP CYCLE:  2
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224434.580397334
# Total Cost:  3761634.580397334
# SCS SWAP CYCLE:  3
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2225940.00467495
# Total Cost:  3763140.00467495
# SCS SWAP CYCLE:  4
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2229159.333230155
# Total Cost:  3766359.333230155
# SCS SWAP CYCLE:  5
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223155.071984049
# Total Cost:  3760355.071984049
# SCS SWAP CYCLE:  6
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223129.857903042
# Total Cost:  3760329.857903042
# SCS SWAP CYCLE:  7
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2224963.537415017
# Total Cost:  3762163.537415017
# SCS SWAP CYCLE:  8
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223769.572555026
# Total Cost:  3760969.572555026
# SCS SWAP CYCLE:  9
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223924.7795784827
# Total Cost:  3761124.7795784827
# SCS SWAP CYCLE:  10
# Building the network
# Network Built
# Cost of Infrastructure:  1537200.0
# Cost of Customer Unsatisfaction:  2223506.5073053474
# Total Cost:  3760706.5073053474

# %%
df_infra = OPTIMUM_NETWORK['Optimum Infra']
df_solution_network = OPTIMUM_NETWORK['Solution Network']
df_solution_infra = OPTIMUM_NETWORK['Solution Infra']

df_infra.to_csv('Optimum_Infra_2020.csv')
df_solution_network.to_csv('Solution Network_2020.csv')
df_solution_infra.to_csv ('Solution Infra_2020.csv')

# %%
df_solution_infra.shape
# Out:
# (400, 6)
